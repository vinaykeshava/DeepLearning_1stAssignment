# %% [markdown]
# > Indented block

# %% [markdown]
# IMPORTING THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# LOADING THE DATA

# %%
df = pd.read_fwf('drive/MyDrive/dl/19.txt')

# %%
df.head()
# Out:
#    2018  137  11  33  28  366  23  -0.04690  -0.03850  0.00582  ...  51.00.1  \
# 0  2018  137  11  33  29  902  26   -0.0469   -0.0385  0.00582  ...     51.0
# 1  2018  137  11  33  31  438  29   -0.0469   -0.0385  0.00582  ...     51.0
# 2  2018  137  11  36  44  974  23   -0.0469   -0.0385  0.00582  ...     51.0
# 3  2018  137  11  36  46  510  26   -0.0469   -0.0385  0.00582  ...     51.0
# 4  2018  137  11  36  48   46  29   -0.0469   -0.0385  0.00582  ...     51.0
#
#    SYNC  ON  ON.1  ON.2  SYNC.1  NOT_USBL  ENA  LOW ON.3
# 0  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 1  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 2  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 3  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 4  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
#
# [5 rows x 28 columns]

# %% [markdown]
# ADDING THE COLUMN NAMES

# %%
df.columns = ['C' + str(n) for n in range(1,29)]

# %%
df.head()
# Out:
#      C1   C2  C3  C4  C5   C6  C7      C8      C9      C10  ...   C19   C20  \
# 0  2018  137  11  33  29  902  26 -0.0469 -0.0385  0.00582  ...  51.0  SYNC
# 1  2018  137  11  33  31  438  29 -0.0469 -0.0385  0.00582  ...  51.0  SYNC
# 2  2018  137  11  36  44  974  23 -0.0469 -0.0385  0.00582  ...  51.0  SYNC
# 3  2018  137  11  36  46  510  26 -0.0469 -0.0385  0.00582  ...  51.0  SYNC
# 4  2018  137  11  36  48   46  29 -0.0469 -0.0385  0.00582  ...  51.0  SYNC
#
#    C21  C22  C23   C24       C25  C26  C27 C28
# 0   ON   ON   ON  SYNC  NOT_USBL  ENA  LOW  ON
# 1   ON   ON   ON  SYNC  NOT_USBL  ENA  LOW  ON
# 2   ON   ON   ON  SYNC  NOT_USBL  ENA  LOW  ON
# 3   ON   ON   ON  SYNC  NOT_USBL  ENA  LOW  ON
# 4   ON   ON   ON  SYNC  NOT_USBL  ENA  LOW  ON
#
# [5 rows x 28 columns]

# %% [markdown]
# REMOVING THE NON-NUMERICAL VALUES

# %%
df.drop(['C1'] + ['C' + str(n) for n in range(20,29)], axis=1, inplace = True)
df.head()
# Out:
#     C2  C3  C4  C5   C6  C7      C8      C9      C10      C11     C12     C13  \
# 0  137  11  33  29  902  26 -0.0469 -0.0385  0.00582  0.01091 -0.0981 -0.0687
# 1  137  11  33  31  438  29 -0.0469 -0.0385  0.00582  0.01091 -0.0981 -0.0687
# 2  137  11  36  44  974  23 -0.0469 -0.0385  0.00582  0.01086 -0.0981 -0.0687
# 3  137  11  36  46  510  26 -0.0469 -0.0385  0.00582  0.01086 -0.0981 -0.0687
# 4  137  11  36  48   46  29 -0.0469 -0.0385  0.00582  0.01086 -0.0981 -0.0687
#
#        C14      C15   C16   C17   C18   C19
# 0  0.00661  0.00809  37.0  51.0  37.0  51.0
# 1  0.00661  0.00809  37.0  51.0  37.0  51.0
# 2  0.00656  0.00809  37.0  51.0  37.0  51.0
# 3  0.00656  0.00809  37.0  51.0  37.0  51.0
# 4  0.00656  0.00809  37.0  51.0  37.0  51.0

# %% [markdown]
# FINDING COUNT, MEAN, STANDARD DEVIATION, MINIMUM AND MAXIMUM VALUES, PERCENTILE

# %%
df.describe()
# Out:
#                 C2           C3           C4           C5           C6  \
# count  6297.000000  6297.000000  6297.000000  6297.000000  6297.000000
# mean    137.510243    10.634588    26.922979    29.638399   497.859616
# std       0.499935     6.204967    17.819598    17.337289   288.901162
# min     137.000000     0.000000     0.000000     0.000000     0.000000
# 25%     137.000000     5.000000    11.000000    14.000000   247.000000
# 50%     138.000000    11.000000    25.000000    30.000000   498.000000
# 75%     138.000000    15.000000    42.000000    45.000000   748.000000
# max     138.000000    23.000000    59.000000    59.000000   999.000000
#
#                 C7           C8           C9          C10          C11  \
# count  6297.000000  6297.000000  6297.000000  6297.000000  6297.000000
# mean     19.381293    -0.050560    -0.034347     0.005654     0.011127
# std       7.316731     0.136703     0.215939     0.000966     0.001125
# ...

# %% [markdown]
# FINDING THE MEDIAN

# %%
df.median(axis = 0)
# Out:
# C2     138.00000
# C3      11.00000
# C4      25.00000
# C5      30.00000
# C6     498.00000
# C7      22.00000
# C8      -0.04690
# C9      -0.03850
# C10      0.00572
# C11      0.01111
# C12     -0.09810
# C13     -0.06870
# C14      0.00656
# C15      0.00799
# C16     37.00000
# C17     51.00000
# C18     37.00000
# C19     51.00000
# dtype: float64

# %%
plt.rcParams['figure.figsize'] = [50, 50]

# %% [markdown]
# NORMALISATION / MINMAXSCALING

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
NDf = min_max_scaler.fit_transform(df)

NDf = pd.DataFrame(NDf)

for i in range(18):
  m = np.mean(NDf[i])
  cols = np.where((NDf[i] >= m - (0.8 * m)) & (NDf[i] <= m + (0.8 * m)), 'm', 'b')
  plt.subplot(4,5,i + 1)
  plt.scatter(NDf.index,NDf[i], c = cols)
plt.show()

# %% [markdown]
# PLOTTING STANDARD SCALER / Z - SCORE

# %%
from sklearn import preprocessing
z_scaler = preprocessing.StandardScaler()
NDf = z_scaler.fit_transform(df)

NDf = pd.DataFrame(NDf)

for i in range(18):
  m = np.mean(NDf[i])
  cols = np.where((NDf[i] >= -0.8) & (NDf[i] <= 0.8), 'm', 'b')
  plt.subplot(4,5,i + 1)
  plt.scatter(NDf.index,NDf[i], c = cols)
plt.show()

# %% [markdown]
# PLOTTING MAX ABSOLUTE VALUE

# %%
from sklearn import preprocessing
z_scaler = preprocessing.MaxAbsScaler()
NDf = z_scaler.fit_transform(df)

NDf = pd.DataFrame(NDf)

for i in range(18):
  m = np.mean(NDf[i])
  cols = np.where((NDf[i] >= m - (0.8 * m)) & (NDf[i] <= m + (0.8 * m)), 'm', 'b')
  plt.subplot(4,5,i + 1)
  plt.scatter(NDf.index,NDf[i], c = cols)
plt.show()
